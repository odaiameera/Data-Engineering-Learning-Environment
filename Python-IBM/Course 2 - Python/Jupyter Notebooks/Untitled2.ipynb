# %%
5 +10 +20
# Out:
# 35

# %%
Ratings = (1,2,3,4,5,6,7,8,9,0)
Radting1 = Ratings
Radtings1+Radting
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 Ratings = (1,2,3,4,5,6,7,8,9,0)
#       2 Radting1 = Ratings
# ----> 3 Radtings1+Radting
#
# NameError: name 'Radtings1' is not defined

# %%
Ratings1+Ratings
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 Ratings1+Ratings
#
# NameError: name 'Ratings1' is not defined

# %%
Ratings
# Out:
# (1, 2, 3, 4, 5, 6, 7, 8, 9, 0)

# %%
Ratings1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 Ratings1
#
# NameError: name 'Ratings1' is not defined

# %%
Ratings1 = Ratings

# %%
Ratings1
# Out:
# (1, 2, 3, 4, 5, 6, 7, 8, 9, 0)
