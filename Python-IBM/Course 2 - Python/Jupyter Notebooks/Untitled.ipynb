# %%
40 + 60 + 16 + 41
# Out:
# 157

# %%
total_min = 157 - 50

# %%
200 - total_min
# Out:
# 93

# %%
total_min
# Out:
# 107

# %%
x = 150

# %%
x:
# Out:
#   Cell In[12], line 1
#     x:
#       ^
# SyntaxError: invalid syntax

# %%
x:
# Out:
#   Cell In[13], line 1
#     x:
#       ^
# SyntaxError: invalid syntax

# %%
x = 150

# %%
x:
# Out:
#   Cell In[15], line 1
#     x:
#       ^
# SyntaxError: invalid syntax

# %%
total_min = 43 + 42 + 57

# %%
total_hr = total_min / 60
total_hr
# Out:
# 2.3666666666666667
