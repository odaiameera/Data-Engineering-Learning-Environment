# %%
say_what=('say','what','you','will')

# %%
say_what[-1]
# Out:
# 'will'

# %%
A=(1,2,3,4,5)
A[1:4]
# Out:
# (2, 3, 4)

# %%
B=[1,2,[3,'a'],[4,'b']]
B[3][1]
# Out:
# 'b'

# %%
[1,2,3]+[1,1,1]
# Out:
# [1, 2, 3, 1, 1, 1]

# %%
A = [1]

# %%
A.append([2, 3, 4, 5])

# %%
A
# Out:
# [1, [2, 3, 4, 5]]
